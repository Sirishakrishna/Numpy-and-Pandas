# %% [markdown]
# # What is pandas-python? Introduction and Installation

# %% [markdown]
# Pandas is python module that makes data science easy and effective

# %% [markdown]
# Weather dataset

# %% [markdown]
# Questions?
#
# 1. What was the maximum temparature in new york in the month of january?
#
# 2. On which days did it rains?
#
# 3. What was the average speed of wind during the month?

# %% [markdown]
# First we will see in python code

# %%
# now we will see in pandas 
import pandas as pd
df = pd.read_csv("https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing")
df
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style>@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic')  \
# 0                                                 try{
# 1                                               var aa
# 2    if("function"==typeof Object.setPrototypeOf)ea...
# 3    la="undefined"!=typeof window&&window===this?t...
# 4                     ma("String.prototype.startsWith"
# 5    var na=function(){na=function(){};la.Symbol||(...
# 6    var oa=function(){function a(d){if(this instan...
# 7                 a instanceof String&&(a+="");var d=0
# 8                                    var ta=function(a
# 9                                         ma("WeakMap"
# 10                                   e("seal");var g=0
# 11                                            ma("Map"
# 12   this.b=g();this.size=0;if(l){l=_.ba(l);for(var...
# 13                                             l.Za.uc
# 14                     t;!(t=n.next()).done;)t=t.value
# 15                                              n.next
# 16                                            ma("Set"
# 17   if(d){d=_.ba(d);for(var e;!(e=d.next()).done;)...
# 18   c.prototype[Symbol.iterator]=c.prototype.value...
# 19                                 ma("Object.entries"
# 20   _.Ba=function(a){var c=typeof a;if("object"==c...
# 21   else if("function"==c&&"undefined"==typeof a.c...
# 22                                       Ha=function(a
# 23                                     _.Ia=function(a
# 24                                      _.u=function(a
# 25   _.La=function(a){var c=null;if("undefined"===t...
# 26   _.Ma=function(a){if(Error.captureStackTrace)Er...
# 27              _.Pa=Array.prototype.filter?function(a
# 28                _.Ra=Array.prototype.some?function(a
# 29   var Ta;Ta="constructor hasOwnProperty isProtot...
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                  ]
# 268                                                NaN
# 269  };</script><div ng-non-bindable=""></div><scri...
# 270                                               try{
# 271                   if(_.qj){var tj;if(tj=_.A(_.qj.f
# 272                     }catch(e){_._DumpException(e)}
# 273                                               try{
# 274                          _.wj=function(a){_.z(this
# 275                     }catch(e){_._DumpException(e)}
# 276                                               try{
# 277                                  var xj=function(a
# 278                                    var Cj=_.F(_.nd
# 279                  (function(){var a=_.od();if(_.B(a
# 280                     }catch(e){_._DumpException(e)}
# 281                                    })(this.gbar_);
# 282                                     // Google Inc.
# 283                            </script></body></html>
#
#                                 local('Roboto-Italic')  \
# 0                                                  NaN
# 1                                                   ea
# 2    ia={};try{ia.__proto__=ha;fa=ia.Rg;break a}cat...
# 3    c){if(c){var d=la;a=a.split(".");for(var e=0;e...
# 4                    function(a){return a?a:function(c
# 5                                        pa=function(a
# 6                               d)}var c=0;return a}()
# 7    e={next:function(){if(d<a.length){var f=d++;re...
# 8     c){return Object.prototype.hasOwnProperty.call(a
# 9     function(a){function c(){}function d(l){if(!ta(l
# 10   h=function(l){this.b=(g+=Math.random()+1).toSt...
# 11   function(a){if(function(){if(!a||"function"!=t...
# 12                                       this.set(m[0]
# 13                                      l.Za.head=null
# 14                                            l.call(m
# 15                                            {done:!1
# 16   function(a){if(function(){if(!a||"function"!=t...
# 17   d);this.size=this.b.size;return this};c.protot...
# 18   e){var f=this;this.b.forEach(function(g){retur...
# 19         function(a){return a?a:function(c){var d=[]
# 20                                                 NaN
# 21                                                   c
# 22                                                   c
# 23       c){var d=Array.prototype.slice.call(arguments
# 24   c){function d(){}d.prototype=c.prototype;a.J=c...
# 25                                      {createHTML:Ka
# 26   _.Ma);else{var c=Error().stack;c&&(this.stack=...
# 27                                                   c
# 28               c){return Array.prototype.some.call(a
# 29                                        c){for(var d
# ..                                                 ...
# 254                                                  1
# 255                                                NaN
# 256                  ["https://youtube.googleapis.com"
# 257                                                  1
# 258                                            [1.0E-4
# 259                                                  1
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                    itemJson: [null
# 265                                                NaN
# 266                                                 []
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                             3))for(var uj=_.mh(tj)
# 272                                                NaN
# 273                                                NaN
# 274                                                  a
# 275                                                NaN
# 276                                                NaN
# 277                                                  c
# 278                                                 Bj
# 279                          18))Gj();else{var c=_.A(a
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:local('Roboto Light')  \
# 0                                                  NaN
# 1                                                   ka
# 2    c){a.__proto__=c;if(a.__proto__!==c)throw new ...
# 3                                                    a
# 4    d){if(null==this)throw new TypeError("b`starts...
# 5                                  c){this.b=a;ka(this
# 6    ra=function(){na();var a=la.Symbol.iterator;a|...
# 7                                                a[f])
# 8                                                 c)};
# 9                                 f)){var m=new c;ka(l
# 10                                       this.set(m[0]
# 11                                    m=new a(_.ba([[l
# 12                  m[1])}};d.prototype.set=function(l
# 13                                         this.size--
# 14                                                t[1]
# 15                   value:m(n)};n=null}return{done:!0
# 16   e=new a(_.ba([d]));if(!e.has(d)||1!=e.size||e....
# 17                                                 NaN
# 18                                                   g
# 19                                   e;for(e in c)ta(c
# 20                                                 NaN
# 21                       d){return a.call.apply(a.bind
# 22   d){if(!a)throw Error();if(2<arguments.length){...
# 23   1);return function(){var e=d.slice();e.push.ap...
# 24                                                   f
# 25                                     createScript:Ka
# 26   Error);_.Ma.prototype.name="CustomError";_.Na=...
# 27             d){return Array.prototype.filter.call(a
# 28                                                   c
# 29                                                   e
# ..                                                 ...
# 254                                                  1
# 255                                                NaN
# 256                                                NaN
# 257                                                  1
# 258  //www.google.com/insights/consumersurveys/asyn...
# 259                                                NaN
# 260                                                  1
# 261                                                  1
# 262                                                NaN
# 263                                                NaN
# 264                                    nyc_weather.csv
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                 vj=0;vj<uj.length;vj++)_.Zh(uj[vj]
# 272                                                NaN
# 273                                                NaN
# 274                                                  0
# 275                                                NaN
# 276                                                NaN
# 277                                     d){_.ud.log(46
# 278                                        17)||new Bj
# 279              19)||0;window.addEventListener("load"
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
#                                  local('Roboto-Light')  \
# 0                                                  NaN
# 1                                                   la
# 2                                                    c
# 3                                     {configurable:!0
# 4                              f=c.length;d=Math.max(0
# 5                                          description
# 6                                                    a
# 7            done:!1}}e.next=function(){return{done:!0
# 8                                                  NaN
# 9                                                    f
# 10                  m[1])}};h.prototype.set=function(l
# 11   s]]));if("s"!=m.get(l)||1!=m.size||m.get({x:4}...
# 12                         m){l=0===l?0:l;var n=e(this
# 13   !0):!1};d.prototype.clear=function(){this.f={}...
# 14                                                t[0]
# 15                                    value:void 0}})}
# 16   g=f.next();if(g.done||g.value[0]!=d||g.value[1...
# 17                                                 NaN
# 18                                                   g
# 19                                       e)&&d.push([e
# 20                                                 NaN
# 21                                        arguments)};
# 22   2);return function(){var f=Array.prototype.sli...
# 23                      arguments);return a.apply(this
# 24              g){for(var h=Array(arguments.length-2)
# 25                                  createScriptURL:Ka
# 26            c){return Array.prototype.indexOf.call(a
# 27                                                   c
# 28                                 void 0)}:function(a
# 29   f=1;f<arguments.length;f++){e=arguments[f];for...
# ..                                                 ...
# 254                                                NaN
# 255                                                  1
# 256                                                 2]
# 257                                                NaN
# 258                                                NaN
# 259                                                  3
# 260         ["AIzaSyCMp6sr4oTC18AWkE2Ii4UBZHTHEpGZWZM"
# 261                                                NaN
# 262                                                  1
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                               ogpc
# 272                                                NaN
# 273                                                NaN
# 274                                                 -1
# 275                                                NaN
# 276                                                NaN
# 277                                             {att:a
# 278                                                 Dj
# 279                    function(){window.setTimeout(Gj
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
#     url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular')  \
# 0                                                  NaN
# 1                                                   ma
# 2    d){a!=Array.prototype&&a!=Object.prototype&&(a...
# 3                                          writable:!0
# 4                                         Math.min(d|0
# 5                                     {configurable:!0
# 6                                     {configurable:!0
# 7    value:void 0}};return e.next()}};e[Symbol.iter...
# 8                                                  NaN
# 9    {value:m})}}function e(l){var m=Object[l];m&&(...
# 10                                    m){d(l);if(!ta(l
# 11         t)!=m||2!=m.size)return!1;var n=m.entries()
# 12   l);n.list||(n.list=this.f[n.id]=[]);n.Za?n.Za....
# 13   l).Za};d.prototype.get=function(l){return(l=e(...
# 14   this)};d.prototype[Symbol.iterator]=d.prototyp...
# 15   g=function(){var l={};return l.uc=l.next=l.hea...
# 16                                                 NaN
# 17                                                 NaN
# 18                    f)})};return c});ma("Array.from"
# 19   c[e]]);return d}});_.ua=_.ua||{};_.p=this||sel...
# 20                                                 NaN
# 21                                                 NaN
# 22                                 e);return a.apply(c
# 23   e)}};_.Ja=Date.now||function(){return+new Date...
# 24   l=2;l<arguments.length;l++)h[l-2]=arguments[l]...
# 25   createURL:Ka})}catch(d){_.p.console&&_.p.conso...
# 26                                                   c
# 27                                      d)}:function(a
# 28                               c){for(var d=a.length
# 29              Object.prototype.hasOwnProperty.call(e
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260        https://blobcomments-pa.clients6.google.com
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                        );_.kj(_.qj
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                              max:c
# 278                                      Aj=(Dj=_.F(Cj
# 279                                         c)})}})();
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
#                                local('Roboto-Regular')  \
# 0                                                  NaN
# 1                                                   Ga
# 2                                                  NaN
# 3                                         value:c})}};
# 4    this.length));for(var g=0;g<f&&d<e;)if(this[d+...
# 5                                          writable:!0
# 6                                          writable:!0
# 7     function(a){return a?a:function(){return sa(this
# 8                                                  NaN
# 9                                    m=Object.seal({})
# 10   f))throw Error("e`"+l);l[f][this.b]=m;return t...
# 11   t=n.next();if(t.done||t.value[0]!=l||"s"!=t.va...
# 12                                        uc:this.b.uc
# 13   l).Za)&&l.value};d.prototype.entries=function(...
# 14   m){var n=m&&typeof m;"object"==n||"function"==...
# 15                                     h=0;return d});
# 16                                                 NaN
# 17                                                 NaN
# 18                   function(a){return a?a:function(c
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22              f)}}return function(){return a.apply(c
# 23   c){a=a.split(".");var d=_.p;a[0]in d||"undefin...
# 24                      h)}};Ka=function(a){return a};
# 25                                                 NaN
# 26                                 void 0)}:function(a
# 27                                                   c
# 28                             e=_.wa(a)?a.split(""):a
# 29                                  d)&&(a[d]=e[d])}};
# ..                                                 ...
# 254                                              [null
# 255                                                NaN
# 256                                                NaN
# 257                                                  1
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                  1
# 262                                                NaN
# 263                                                  0
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                              !!_.qj.b&&_.qj.b.Zb()
# 272                                                NaN
# 273                                                NaN
# 274                                    null)};_.u(_.wj
# 275                                                NaN
# 276                                                NaN
# 277                                           url:d})}
# 278                                               _.wj
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# ...
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
#     null.34 null.35 [""]]]  \
# 0       NaN     NaN    NaN
# 1       NaN     NaN    NaN
# 2       NaN     NaN    NaN
# 3       NaN     NaN    NaN
# 4       NaN     NaN    NaN
# 5       NaN     NaN    NaN
# 6       NaN     NaN    NaN
# 7       NaN     NaN    NaN
# 8       NaN     NaN    NaN
# 9       NaN     NaN    NaN
# 10      NaN     NaN    NaN
# 11      NaN     NaN    NaN
# 12      NaN     NaN    NaN
# 13      NaN     NaN    NaN
# 14      NaN     NaN    NaN
# 15      NaN     NaN    NaN
# 16      NaN     NaN    NaN
# 17      NaN     NaN    NaN
# 18      NaN     NaN    NaN
# 19      NaN     NaN    NaN
# 20      NaN     NaN    NaN
# 21      NaN     NaN    NaN
# 22      NaN     NaN    NaN
# 23      NaN     NaN    NaN
# 24      NaN     NaN    NaN
# 25      NaN     NaN    NaN
# 26      NaN     NaN    NaN
# 27      NaN     NaN    NaN
# 28      NaN     NaN    NaN
# 29      NaN     NaN    NaN
# ..      ...     ...    ...
# 254     NaN     NaN    NaN
# 255     NaN     NaN    NaN
# 256     NaN     NaN    NaN
# 257     NaN     NaN    NaN
# 258     NaN     NaN    NaN
# 259     NaN     NaN    NaN
# 260     NaN     NaN    NaN
# 261     NaN     NaN    NaN
# 262     NaN     NaN    NaN
# 263     NaN     NaN    NaN
# 264     NaN     NaN    NaN
# 265     NaN     NaN    NaN
# 266     NaN     NaN    NaN
# 267     NaN     NaN    NaN
# 268     NaN     NaN    NaN
# 269     NaN     NaN    NaN
# 270     NaN     NaN    NaN
# 271     NaN     NaN    NaN
# 272     NaN     NaN    NaN
# 273     NaN     NaN    NaN
# 274     NaN     NaN    NaN
# 275     NaN     NaN    NaN
# 276     NaN     NaN    NaN
# 277     NaN     NaN    NaN
# 278     NaN     NaN    NaN
# 279     NaN     NaN    NaN
# 280     NaN     NaN    NaN
# 281     NaN     NaN    NaN
# 282     NaN     NaN    NaN
# 283     NaN     NaN    NaN
#
#     };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 254                                                NaN
# 255                                                NaN
# 256                                                NaN
# 257                                                NaN
# 258                                                NaN
# 259                                                NaN
# 260                                                NaN
# 261                                                NaN
# 262                                                NaN
# 263                                                NaN
# 264                                                NaN
# 265                                                NaN
# 266                                                NaN
# 267                                                NaN
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
# 278                                                NaN
# 279                                                NaN
# 280                                                NaN
# 281                                                NaN
# 282                                                NaN
# 283                                                NaN
#
# [284 rows x 399 columns]

# %%
from google.colab import drive
drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f83e04cff7df> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('https://drive.google.com/file/d/1KxwFsL6IF7OD_XN28kjxl0-amnELIhZ8/view?usp=sharing')
#
# ModuleNotFoundError: No module named 'google'

# %%
#get the maximum temparature 
df['Temperature'].max()
# Out:
# 50

# %%
#to know which day it rains
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
#3. average wind speed
df['WindSpeedMPH'].mean()
# Out:
# 6.8928571428571432

# %% [markdown]
# # Installation

# %% [markdown]
# pip3 install pandas
